# %%
import os
import sys
import warnings
import pandas as pd
import numpy as np
from sklearn.exceptions import DataConversionWarning
from sklearn.metrics import mean_absolute_error
import featuretools as ft
import featuretools.variable_types as vtypes

PROJECT_PATH = os.path.join(os.getcwd(), '../')

if PROJECT_PATH not in sys.path:
    sys.path.append(PROJECT_PATH)
    
from server.ml_models.all_model import AllModelData
from server.ml_models.match_model import MatchModelData
from server.ml_models import EnsembleModel

from src.model.metrics import yearly_performance_scores
from src.model.charts import graph_yearly_model_performance

SEED = 42

np.random.seed(SEED)
warnings.simplefilter("ignore", DataConversionWarning)

# %% [markdown]
# ## Baseline with existing features

# %%
data = AllModelData(train_years=(None, 2016))
data.data
# Out:
# /usr/local/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:146: RRuntimeWarning: Returning data from 1965-01-01 to 2016-12-31
#
#   warnings.warn(x, RRuntimeWarning)
# /usr/local/lib/python3.6/site-packages/rpy2/rinterface/__init__.py:146: RRuntimeWarning: Finished getting afltables data
#
#   warnings.warn(x, RRuntimeWarning)
# /usr/local/lib/python3.6/site-packages/rpy2/robjects/pandas2ri.py:191: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   res = PandasDataFrame.from_items(items)
#                                         team         oppo_team round_type  \
# Adelaide         1991 1.0           Adelaide          Hawthorn    Regular
#                       2.0           Adelaide           Carlton    Regular
#                       3.0           Adelaide            Sydney    Regular
#                       4.0           Adelaide          Essendon    Regular
#                       5.0           Adelaide        West Coast    Regular
#                       6.0           Adelaide  Western Bulldogs    Regular
#                       7.0           Adelaide          St Kilda    Regular
#                       9.0           Adelaide   North Melbourne    Regular
#                       10.0          Adelaide         Melbourne    Regular
#                       11.0          Adelaide           Geelong    Regular
#                       12.0          Adelaide           Fitzroy    Regular
#                       13.0          Adelaide          Richmond    Regular
#                       14.0          Adelaide          Brisbane    Regular
#                       15.0          Adelaide       Collingwood    Regular
#                       16.0          Adelaide          Hawthorn    Regular
#                       17.0          Adelaide           Carlton    Regular
#                       18.0          Adelaide            Sydney    Regular
#                       19.0          Adelaide          Essendon    Regular
#                       20.0          Adelaide        West Coast    Regular
#                       21.0          Adelaide  Western Bulldogs    Regular
#                       22.0          Adelaide          St Kilda    Regular
#                       24.0          Adelaide   North Melbourne    Regular
#                  1992 1.0           Adelaide  Western Bulldogs    Regular
#                       3.0           Adelaide         Melbourne    Regular
#                       4.0           Adelaide           Fitzroy    Regular
#                       5.0           Adelaide          Richmond    Regular
#                       6.0           Adelaide          Brisbane    Regular
#                       7.0           Adelaide          St Kilda    Regular
#                       8.0           Adelaide           Geelong    Regular
#                       9.0           Adelaide       Collingwood    Regular
# ...                                      ...               ...        ...
# Western Bulldogs 2015 21.0  Western Bulldogs        West Coast    Regular
#                       22.0  Western Bulldogs   North Melbourne    Regular
#                       23.0  Western Bulldogs          Brisbane    Regular
#                       24.0  Western Bulldogs          Adelaide     Finals
#                  2016 1.0   Western Bulldogs         Fremantle    Regular
#                       2.0   Western Bulldogs          St Kilda    Regular
#                       3.0   Western Bulldogs          Hawthorn    Regular
#                       4.0   Western Bulldogs           Carlton    Regular
#                       5.0   Western Bulldogs          Brisbane    Regular
#                       6.0   Western Bulldogs   North Melbourne    Regular
#                       7.0   Western Bulldogs          Adelaide    Regular
#                       8.0   Western Bulldogs         Melbourne    Regular
#                       9.0   Western Bulldogs               GWS    Regular
#                       10.0  Western Bulldogs       Collingwood    Regular
#                       11.0  Western Bulldogs        West Coast    Regular
#                       12.0  Western Bulldogs     Port Adelaide    Regular
#                       13.0  Western Bulldogs           Geelong    Regular
#                       15.0  Western Bulldogs            Sydney    Regular
#                       16.0  Western Bulldogs          Richmond    Regular
#                       17.0  Western Bulldogs        Gold Coast    Regular
#                       18.0  Western Bulldogs          St Kilda    Regular
#                       19.0  Western Bulldogs           Geelong    Regular
#                       20.0  Western Bulldogs   North Melbourne    Regular
#                       21.0  Western Bulldogs       Collingwood    Regular
#                       22.0  Western Bulldogs          Essendon    Regular
#                       23.0  Western Bulldogs         Fremantle    Regular
#                       24.0  Western Bulldogs        West Coast     Finals
#                       25.0  Western Bulldogs          Hawthorn     Finals
#                       26.0  Western Bulldogs               GWS     Finals
#                       27.0  Western Bulldogs            Sydney     Finals
#
#                                         venue  win_odds  line_odds  \
# Adelaide         1991 1.0       Football Park      0.00        0.0
#                       2.0       Football Park      0.00        0.0
#                       3.0              S.C.G.      0.00        0.0
#                       4.0          Windy Hill      0.00        0.0
#                       5.0             Subiaco      0.00        0.0
#                       6.0       Football Park      0.00        0.0
#                       7.0      Moorabbin Oval      0.00        0.0
#                       9.0              M.C.G.      0.00        0.0
#                       10.0      Football Park      0.00        0.0
#                       11.0      Kardinia Park      0.00        0.0
#                       12.0      Football Park      0.00        0.0
#                       13.0             M.C.G.      0.00        0.0
#                       14.0      Football Park      0.00        0.0
#                       15.0      Victoria Park      0.00        0.0
#                       16.0      Waverley Park      0.00        0.0
#                       17.0       Princes Park      0.00        0.0
#                       18.0      Football Park      0.00        0.0
#                       19.0      Football Park      0.00        0.0
#                       20.0      Football Park      0.00        0.0
#                       21.0       Western Oval      0.00        0.0
#                       22.0      Football Park      0.00        0.0
#                       24.0      Football Park      0.00        0.0
#                  1992 1.0       Football Park      0.00        0.0
#                       3.0        Princes Park      0.00        0.0
#                       4.0        Princes Park      0.00        0.0
#                       5.0       Football Park      0.00        0.0
#                       6.0       Football Park      0.00        0.0
#                       7.0      Moorabbin Oval      0.00        0.0
#                       8.0       Kardinia Park      0.00        0.0
#                       9.0       Football Park      0.00        0.0
# ...                                       ...       ...        ...
# Western Bulldogs 2015 21.0            Subiaco      3.60       23.5
#                       22.0          Docklands      2.30        6.5
#                       23.0              Gabba      1.22      -28.5
#                       24.0             M.C.G.      1.93       -1.5
#                  2016 1.0           Docklands      1.65       -7.5
#                       2.0           Docklands      1.25      -25.5
#                       3.0           Docklands      1.96        1.5
#                       4.0           Docklands      1.08      -49.5
#                       5.0           Docklands      1.13      -42.5
#                       6.0           Docklands      2.05        2.5
#                       7.0           Docklands      1.72       -4.5
#                       8.0              M.C.G.      1.42      -16.5
#                       9.0   Sydney Showground      3.10       18.5
#                       10.0             M.C.G.      1.48      -13.5
#                       11.0          Docklands      1.73       -5.5
#                       12.0      Adelaide Oval      2.20        5.5
#                       13.0          Docklands      2.40        9.5
#                       13.0               0.000000                    0.000000
#                       14.0               0.000000                    0.000000
#                       15.0               0.000000                    0.000000
#                       16.0               0.000000                    0.000000
#                       17.0               0.000000                    0.000000
#                       18.0               0.000000                    0.000000
#                       19.0               0.000000                    0.000000
#                       20.0               0.000000                    0.000000
#                       21.0               0.000000                    0.000000
#                       22.0               0.000000                    0.000000
#                       24.0               0.000000                    0.000000
#                  1992 1.0                0.000000                    0.000000
#                       3.0                0.000000                    0.000000
#                       4.0                0.000000                    0.000000
#                       5.0                0.000000                    0.000000
#                       6.0                0.000000                    0.000000
#                       7.0                0.000000                    0.000000
#                       8.0                0.000000                    0.000000
#                       9.0                0.000000                    0.000000
# ...                                           ...                         ...
# Western Bulldogs 2015 21.0               0.434783                    0.739130
#                       22.0               0.434783                    0.608696
#                       23.0               0.478261                    0.130435
#                       24.0               0.456522                    0.586957
#                  2016 1.0                0.500000                    0.739130
#                       2.0                0.543478                    0.086957
#                       3.0                0.543478                    0.956522
#                       4.0                0.586957                    0.130435
#                       5.0                0.630435                    0.086957
#                       6.0                0.586957                    0.695652
#                       7.0                0.630435                    0.391304
#                       8.0                0.630435                    0.217391
#                       9.0                0.630435                    0.565217
#                       10.0               0.673913                    0.434783
#                       11.0               0.673913                    0.695652
#                       12.0               0.630435                    0.739130
#                       13.0               0.586957                    0.782609
#                       15.0               0.543478                    0.847826
#                       16.0               0.586957                    0.652174
#                       17.0               0.630435                    0.347826
#                       18.0               0.630435                    0.130435
#                       19.0               0.586957                    0.826087
#                       20.0               0.543478                    0.608696
#                       21.0               0.586957                    0.347826
#                       22.0               0.630435                    0.043478
#                       23.0               0.630435                    0.173913
#                       24.0               0.608696                    0.782609
#                       25.0               0.565217                    0.826087
#                       26.0               0.521739                    0.695652
#                       27.0               0.521739                    0.847826
#
#                             ...  oppo_last_week_result  oppo_last_week_score  \
# Adelaide         1991 1.0   ...                    0.0                  64.0
#                       2.0   ...                    0.0                 113.0
#                       3.0   ...                    0.0                  75.0
#                       4.0   ...                    1.0                 167.0
#                       5.0   ...                    1.0                 127.0
#                       6.0   ...                    1.0                 118.0
#                       7.0   ...                    0.0                  60.0
#                       9.0   ...                    1.0                 150.0
#                       10.0  ...                    1.0                 121.0
#                       11.0  ...                    0.0                 106.0
#                       12.0  ...                    1.0                 127.0
#                       13.0  ...                    1.0                  96.0
#                       14.0  ...                    0.0                  62.0
#                       15.0  ...                    1.0                 143.0
#                       16.0  ...                    1.0                 179.0
#                       17.0  ...                    0.0                  89.0
#                       18.0  ...                    0.0                 103.0
#                       19.0  ...                    1.0                 123.0
#                       20.0  ...                    0.0                  82.0
#                       21.0  ...                    0.0                  69.0
#                       22.0  ...                    1.0                 155.0
#                       24.0  ...                    0.0                  58.0
#                  1992 1.0   ...                    1.0                  98.0
#                       3.0   ...                    1.0                 113.0
#                       4.0   ...                    0.0                  58.0
#                       5.0   ...                    1.0                 119.0
#                       6.0   ...                    0.5                  92.0
#                       7.0   ...                    0.0                 113.0
#                       8.0   ...                    1.0                 239.0
#                       9.0   ...                    0.0                  72.0
# ...                         ...                    ...                   ...
# Western Bulldogs 2015 21.0  ...                    1.0                 104.0
#                       22.0  ...                    1.0                  94.0
#                       23.0  ...                    0.0                  62.0
#                       24.0  ...                    0.0                  80.0
#                  2016 1.0   ...                    0.0                  67.0
#                       2.0   ...                    0.0                 100.0
#                       3.0   ...                    1.0                  99.0
#                       4.0   ...                    0.0                  41.0
#                       5.0   ...                    1.0                 107.0
#                       6.0   ...                    1.0                 119.0
#                       7.0   ...                    1.0                  97.0
#                       8.0   ...                    1.0                 160.0
#                       9.0   ...                    1.0                 149.0
#                       10.0  ...                    1.0                 104.0
#                       11.0  ...                    1.0                 132.0
#                       12.0  ...                    1.0                 125.0
#                       13.0  ...                    1.0                 105.0
#                       15.0  ...                    1.0                  86.0
#                       16.0  ...                    0.0                  56.0
#                       17.0  ...                    1.0                 139.0
#                       18.0  ...                    1.0                 110.0
#                       19.0  ...                    1.0                  85.0
#                       20.0  ...                    1.0                  85.0
#                       21.0  ...                    0.0                  77.0
#                       22.0  ...                    1.0                  75.0
#                       23.0  ...                    0.0                  37.0
#                       24.0  ...                    1.0                 100.0
#                       25.0  ...                    0.0                  83.0
#                       26.0  ...                    1.0                  91.0
#                       27.0  ...                    1.0                  97.0
#
#                             oppo_cum_win_points  \
# Adelaide         1991 1.0                   0.0
#                       2.0                   0.0
#                       3.0                   0.0
#                       4.0                   8.0
#                       5.0                  12.0
#                       6.0                  12.0
#                       7.0                  10.0
#                       9.0                  16.0
#                       10.0                 24.0
#                       11.0                 20.0
#                       12.0                  8.0
#                       13.0                 20.0
#                       14.0                  4.0
#                       15.0                 26.0
#                       16.0                 36.0
#                       17.0                 28.0
#                       18.0                 18.0
#                       19.0                 40.0
#                       20.0                 60.0
#                       21.0                 34.0
#                       22.0                 46.0
#                       24.0                 48.0
#                  1992 1.0                   4.0
#                       3.0                   4.0
#                       4.0                   8.0
#                       5.0                   8.0
#                       6.0                   6.0
#                       7.0                  12.0
#                       8.0                  16.0
#                       9.0                  20.0
# ...                                         ...
# Western Bulldogs 2015 21.0                 62.0
#                       22.0                 52.0
#                       23.0                 12.0
#                       24.0                 56.0
#                  2016 1.0                   0.0
#                       2.0                   0.0
#                       3.0                   8.0
#                       4.0                   0.0
#                       5.0                   8.0
#                       6.0                  20.0
#                       7.0                  16.0
#                       8.0                  20.0
#                       9.0                  24.0
#                       10.0                 16.0
#                       11.0                 28.0
#                       12.0                 28.0
#                       13.0                 40.0
#                       15.0                 40.0
#                       16.0                 24.0
#                       17.0                 20.0
#                       18.0                 32.0
#                       19.0                 52.0
#                       20.0                 48.0
#                       21.0                 32.0
#                       22.0                 12.0
#                       23.0                 12.0
#                       24.0                 64.0
#                       25.0                 72.0
#                       26.0                 68.0
#                       27.0                 76.0
#
#                             oppo_rolling_last_week_win_rate  oppo_win_streak  \
# Adelaide         1991 1.0                          0.608696             -2.0
#                       12.0          1.188406                     7
#                       13.0          1.148117                     1
#                       15.0          1.055200                     1
#                       16.0          1.073211                    11
#                       17.0          1.000742                    15
#                       18.0          0.926861                    11
#                       19.0          1.118421                     2
#                       20.0          1.013761                     7
#                       21.0          1.120667                    12
#                       22.0          0.801398                    17
#                       23.0          0.752513                    18
#                       24.0          1.074269                     6
#                       25.0          1.020193                     1
#                       26.0          1.123952                     3
#                       27.0          1.054772                     1
#
# [29950 rows x 83 columns]

# %%
# Data with venue & date added

ens_model = EnsembleModel()

scores = yearly_performance_scores([('ensemble', ens_model, {})], *data.train_data(), data_frame=True)
scores
# Out:
#    accuracy      error     model  year
# 0  0.785714  29.400674  ensemble  2011
# 1  0.792271  27.575879  ensemble  2012
# 2  0.753623  26.116556  ensemble  2013
# 3  0.731884  28.744106  ensemble  2014
# 4  0.713592  30.198007  ensemble  2015
# 5  0.736715  27.866010  ensemble  2016

# %% [markdown]
# ## Add features via basic featuretools implementation

# %%
data.data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 29950 entries, (Adelaide, 1991, 1.0) to (Western Bulldogs, 2016, 27.0)
# Data columns (total 83 columns):
# team                                               29950 non-null object
# oppo_team                                          29950 non-null object
# round_type                                         29950 non-null object
# venue                                              29950 non-null object
# win_odds                                           29950 non-null float64
# line_odds                                          29950 non-null float64
# oppo_win_odds                                      29950 non-null float64
# oppo_line_odds                                     29950 non-null float64
# rolling_pred_win_rate                              29950 non-null float64
# oppo_rolling_pred_win_rate                         29950 non-null float64
# rolling_prev_match_kicks                           29950 non-null float64
# rolling_prev_match_marks                           29950 non-null float64
# rolling_prev_match_handballs                       29950 non-null float64
# rolling_prev_match_goals                           29950 non-null float64
# rolling_prev_match_behinds                         29950 non-null float64
# rolling_prev_match_hit_outs                        29950 non-null float64
# rolling_prev_match_tackles                         29950 non-null float64
# rolling_prev_match_rebounds                        29950 non-null float64
# rolling_prev_match_inside_50s                      29950 non-null float64
# rolling_prev_match_clearances                      29950 non-null float64
# rolling_prev_match_clangers                        29950 non-null float64
# rolling_prev_match_frees_for                       29950 non-null float64
# rolling_prev_match_frees_against                   29950 non-null float64
# rolling_prev_match_contested_possessions           29950 non-null float64
# rolling_prev_match_uncontested_possessions         29950 non-null float64
# rolling_prev_match_contested_marks                 29950 non-null float64
# rolling_prev_match_marks_inside_50                 29950 non-null float64
# rolling_prev_match_one_percenters                  29950 non-null float64
# rolling_prev_match_bounces                         29950 non-null float64
# rolling_prev_match_goal_assists                    29950 non-null float64
# rolling_prev_match_time_on_ground                  29950 non-null float64
# last_year_brownlow_votes                           29950 non-null float64
# oppo_rolling_prev_match_kicks                      29950 non-null float64
# oppo_rolling_prev_match_marks                      29950 non-null float64
# oppo_rolling_prev_match_handballs                  29950 non-null float64
# oppo_rolling_prev_match_goals                      29950 non-null float64
# oppo_rolling_prev_match_behinds                    29950 non-null float64
# oppo_rolling_prev_match_hit_outs                   29950 non-null float64
# oppo_rolling_prev_match_tackles                    29950 non-null float64
# oppo_rolling_prev_match_rebounds                   29950 non-null float64
# oppo_rolling_prev_match_inside_50s                 29950 non-null float64
# oppo_rolling_prev_match_clearances                 29950 non-null float64
# oppo_rolling_prev_match_clangers                   29950 non-null float64
# oppo_rolling_prev_match_frees_for                  29950 non-null float64
# oppo_rolling_prev_match_frees_against              29950 non-null float64
# oppo_rolling_prev_match_contested_possessions      29950 non-null float64
# oppo_rolling_prev_match_uncontested_possessions    29950 non-null float64
# oppo_rolling_prev_match_contested_marks            29950 non-null float64
# oppo_rolling_prev_match_marks_inside_50            29950 non-null float64
# oppo_rolling_prev_match_one_percenters             29950 non-null float64
# oppo_rolling_prev_match_bounces                    29950 non-null float64
# oppo_rolling_prev_match_goal_assists               29950 non-null float64
# oppo_rolling_prev_match_time_on_ground             29950 non-null float64
# oppo_last_year_brownlow_votes                      29950 non-null float64
# date                                               29950 non-null datetime64[ns]
# score                                              29950 non-null int32
# oppo_score                                         29950 non-null int32
# year                                               29950 non-null int64
# round_number                                       29950 non-null int32
# at_home                                            29950 non-null float64
# out_of_state                                       29950 non-null int64
# travel_distance                                    29950 non-null float64
# last_week_goals                                    29950 non-null float64
# last_week_behinds                                  29950 non-null float64
# last_week_result                                   29950 non-null float64
# last_week_score                                    29950 non-null float64
# cum_win_points                                     29950 non-null float64
# rolling_last_week_win_rate                         29950 non-null float64
# win_streak                                         29950 non-null float64
# elo_rating                                         29950 non-null float64
# oppo_travel_distance                               29950 non-null float64
# oppo_last_week_goals                               29950 non-null float64
# oppo_last_week_behinds                             29950 non-null float64
# oppo_last_week_result                              29950 non-null float64
# oppo_last_week_score                               29950 non-null float64
# oppo_cum_win_points                                29950 non-null float64
# oppo_rolling_last_week_win_rate                    29950 non-null float64
# oppo_win_streak                                    29950 non-null float64
# oppo_elo_rating                                    29950 non-null float64
# cum_percent                                        29950 non-null float64
# ladder_position                                    29950 non-null int64
# oppo_cum_percent                                   29950 non-null float64
# oppo_ladder_position                               29950 non-null int64
# dtypes: datetime64[ns](1), float64(71), int32(3), int64(4), object(4)
# memory usage: 18.7+ MB

# %%
def match_id(row):
    home_team = row['team'] if row['at_home'] else row['oppo_team']
    away_team = row['oppo_team'] if row['at_home'] else row['team']

    return str(row['year']) + '.' + str(row['round_number']) + '.' + home_team + away_team


def match_ids(data_frame):
    return pd.Series([match_id(row) for _, row in data_frame.iterrows()], index=data_frame.index)


ft_df = data.data.assign(
    team_match_id=lambda df: df['team'] + '.' + df['year'].astype(str) + '.' + df['round_number'].astype(str),
    match_id=match_ids,
    day_after_match=lambda df: df['date'] + pd.Timedelta(days=1),
).merge((data.data.groupby(['year', 'round_number'])['date'].min() - pd.Timedelta(days=1))
        .rename('round_start_date')
        .reset_index(),
       on=['year', 'round_number'],
       how='left')

ft_df
# Out:
#                    team         oppo_team round_type              venue  \
# 0              Adelaide          Hawthorn    Regular      Football Park
# 1              Adelaide           Carlton    Regular      Football Park
# 2              Adelaide            Sydney    Regular             S.C.G.
# 3              Adelaide          Essendon    Regular         Windy Hill
# 4              Adelaide        West Coast    Regular            Subiaco
# 5              Adelaide  Western Bulldogs    Regular      Football Park
# 6              Adelaide          St Kilda    Regular     Moorabbin Oval
# 7              Adelaide   North Melbourne    Regular             M.C.G.
# 8              Adelaide         Melbourne    Regular      Football Park
# 9              Adelaide           Geelong    Regular      Kardinia Park
# 10             Adelaide           Fitzroy    Regular      Football Park
# 11             Adelaide          Richmond    Regular             M.C.G.
# 12             Adelaide          Brisbane    Regular      Football Park
# 13             Adelaide       Collingwood    Regular      Victoria Park
# 14             Adelaide          Hawthorn    Regular      Waverley Park
# 15             Adelaide           Carlton    Regular       Princes Park
# 16             Adelaide            Sydney    Regular      Football Park
# 17             Adelaide          Essendon    Regular      Football Park
# 18             Adelaide        West Coast    Regular      Football Park
# 19             Adelaide  Western Bulldogs    Regular       Western Oval
# 20             Adelaide          St Kilda    Regular      Football Park
# 21             Adelaide   North Melbourne    Regular      Football Park
# 22             Adelaide  Western Bulldogs    Regular      Football Park
# 23             Adelaide         Melbourne    Regular       Princes Park
# 24             Adelaide           Fitzroy    Regular       Princes Park
# 25             Adelaide          Richmond    Regular      Football Park
# 26             Adelaide          Brisbane    Regular      Football Park
# 27             Adelaide          St Kilda    Regular     Moorabbin Oval
# 28             Adelaide           Geelong    Regular      Kardinia Park
# 29             Adelaide       Collingwood    Regular      Football Park
# ...                 ...               ...        ...                ...
# 29920  Western Bulldogs        West Coast    Regular            Subiaco
# 29921  Western Bulldogs   North Melbourne    Regular          Docklands
# 29922  Western Bulldogs          Brisbane    Regular              Gabba
# 29923  Western Bulldogs          Adelaide     Finals             M.C.G.
# 29924  Western Bulldogs         Fremantle    Regular          Docklands
# 29925  Western Bulldogs          St Kilda    Regular          Docklands
# 29926  Western Bulldogs          Hawthorn    Regular          Docklands
# 29927  Western Bulldogs           Carlton    Regular          Docklands
# 29928  Western Bulldogs          Brisbane    Regular          Docklands
# 29929  Western Bulldogs   North Melbourne    Regular          Docklands
# 29930  Western Bulldogs          Adelaide    Regular          Docklands
# 29931  Western Bulldogs         Melbourne    Regular             M.C.G.
# 29932  Western Bulldogs               GWS    Regular  Sydney Showground
# 29933  Western Bulldogs       Collingwood    Regular             M.C.G.
# 29934  Western Bulldogs        West Coast    Regular          Docklands
# 29935  Western Bulldogs     Port Adelaide    Regular      Adelaide Oval
# 29936  Western Bulldogs           Geelong    Regular          Docklands
# 29937  Western Bulldogs            Sydney    Regular             S.C.G.
# 29938  Western Bulldogs          Richmond    Regular          Docklands
# 29939  Western Bulldogs        Gold Coast    Regular   Cazaly's Stadium
# 29940  Western Bulldogs          St Kilda    Regular          Docklands
# 29941  Western Bulldogs           Geelong    Regular      Kardinia Park
# 29942  Western Bulldogs   North Melbourne    Regular          Docklands
# 29943  Western Bulldogs       Collingwood    Regular          Docklands
# 29944  Western Bulldogs          Essendon    Regular          Docklands
# 29945  Western Bulldogs         Fremantle    Regular            Subiaco
# 1                   0.000000                    0.000000  ...
# 2                   0.000000                    0.000000  ...
# 3                   0.000000                    0.000000  ...
# 4                   0.000000                    0.000000  ...
# 5                   0.000000                    0.000000  ...
# 6                   0.000000                    0.000000  ...
# 7                   0.000000                    0.000000  ...
# 8                   0.000000                    0.000000  ...
# 9                   0.000000                    0.000000  ...
# 10                  0.000000                    0.000000  ...
# 11                  0.000000                    0.000000  ...
# 12                  0.000000                    0.000000  ...
# 13                  0.000000                    0.000000  ...
# 14                  0.000000                    0.000000  ...
# 15                  0.000000                    0.000000  ...
# 16                  0.000000                    0.000000  ...
# 17                  0.000000                    0.000000  ...
# 18                  0.000000                    0.000000  ...
# 19                  0.000000                    0.000000  ...
# 20                  0.000000                    0.000000  ...
# 21                  0.000000                    0.000000  ...
# 22                  0.000000                    0.000000  ...
# 23                  0.000000                    0.000000  ...
# 24                  0.000000                    0.000000  ...
# 25                  0.000000                    0.000000  ...
# 26                  0.000000                    0.000000  ...
# 27                  0.000000                    0.000000  ...
# 28                  0.000000                    0.000000  ...
# 29                  0.000000                    0.000000  ...
# ...                      ...                         ...  ...
# 29920               0.434783                    0.739130  ...
# 29921               0.434783                    0.608696  ...
# 29922               0.478261                    0.130435  ...
# 29923               0.456522                    0.586957  ...
# 29924               0.500000                    0.739130  ...
# 29925               0.543478                    0.086957  ...
# 29926               0.543478                    0.956522  ...
# 29927               0.586957                    0.130435  ...
# 29928               0.630435                    0.086957  ...
# 29929               0.586957                    0.695652  ...
# 29930               0.630435                    0.391304  ...
# 29931               0.630435                    0.217391  ...
# 29932               0.630435                    0.565217  ...
# 29933               0.673913                    0.434783  ...
# 29934               0.673913                    0.695652  ...
# 29935               0.630435                    0.739130  ...
# 29936               0.586957                    0.782609  ...
# 29937               0.543478                    0.847826  ...
# 29938               0.586957                    0.652174  ...
# 29939               0.630435                    0.347826  ...
# 29940               0.630435                    0.130435  ...
# 29941               0.586957                    0.826087  ...
# 29942               0.543478                    0.608696  ...
# 29943               0.586957                    0.347826  ...
# 29944               0.630435                    0.043478  ...
# 29945               0.630435                    0.173913  ...
# 29946               0.608696                    0.782609  ...
# 29947               0.565217                    0.826087  ...
# 29948               0.521739                    0.695652  ...
# 29949               0.521739                    0.847826  ...
#
#        oppo_win_streak  oppo_elo_rating  cum_percent  ladder_position  \
# 0                 -2.0       995.596782     0.000000                7
# 1                 -2.0       986.669176     0.875706                5
# 2                 -2.0       952.109256     0.936508                8
# 3                  2.0      1000.158658     0.878282                6
# 4                  3.0       998.714698     0.760073                9
# 5                  2.0       972.291459     0.722892               10
# 6                 -1.0       976.905181     0.839779                7
# 7                  3.0       975.410314     0.731121               12
# 8                  5.0       993.725636     0.760804               12
# 9                 -1.0       974.011800     0.783833               12
# 10                 1.0       919.733326     0.778502               10
# 11                 1.0       967.097106     0.759819               10
# 12                -2.0       945.690686     0.787157                8
# 13                 2.0       981.247370     0.815566                7
# 14                 3.0       997.491984     0.751756               11
# 15                -1.0       974.775136     0.767390                9
# 16                -3.0       944.939231     0.754737                8
# 17                 1.0       985.127958     0.767177                8
# 18                -1.0      1013.861173     0.788599                8
# 19                -1.0       960.317227     0.800368                9
# 20                 1.0       980.157408     0.764277                9
# 21                -2.0       960.073907     0.779640                9
# 22                 1.0       976.890709     1.836735                2
# 23                 1.0       987.013510     1.265403                5
# 24                -1.0       962.748230     1.379182                3
# 25                 1.0       957.071683     1.206186                6
# 26                 1.5       953.924131     1.289583                2
# 27                -1.0       987.926803     1.269815                2
# 28                 4.0      1014.872296     0.983173                6
# 29                -1.0       988.853109     1.001106                7
# ...                ...              ...          ...              ...
# 29920              1.0      1007.328404     1.034165                4
# 29921              7.0       985.534444     1.027864                8
# 29922             -2.0       930.417544     1.044000                7
# 29923             -1.0       987.550922     1.062500                7
# 29924             -1.0       989.520329     1.522388                9
# 29925             -3.0       964.148982     1.227545                7
# 29926              1.0      1006.268437     1.120301                6
# 29927             -5.0       951.425228     1.263844                7
# 29928              1.0       955.033355     1.142512                8
# 29929              5.0       993.321031     1.112570                5
# 29930              1.0       998.350302     1.012698                9
# 29931              1.0       974.769687     0.963291                8
# 29932              5.0       996.129985     0.931842                6
# 29933              2.0       972.615156     0.908917                8
# 29934              3.0      1001.471869     0.869787                7
# 29935              2.0       989.220330     0.850000                5
# 29936              2.0       998.515609     0.857651                5
# 29937              1.0       998.222624     0.837022                3
# 29938             -1.0       965.655572     0.860375                7
# 29939              2.0       943.373886     0.839858                5
# 29940              2.0       958.416151     0.847996                4
# 29941              2.0       997.966402     0.841574                7
# 29942              2.0       986.762488     0.844863                8
# 29943             -1.0       969.068446     0.842878                7
# 29944              1.0       919.536866     0.857885                7
# 29945             -8.0       937.595259     0.886311                7
# 29946              4.0       998.273225     0.868736                7
# 29947             -1.0       992.118509     0.880240                4
# 29948              3.0      1002.364673     0.891313                4
# 29949              2.0      1009.921744     0.892320                2
#
#        oppo_cum_percent  oppo_ladder_position             team_match_id  \
# 0              0.000000                     8           Adelaide.1991.1
# 1              0.729032                    11           Adelaide.1991.2
# 2              1.226667                    13           Adelaide.1991.3
# 3              1.009434                     3           Adelaide.1991.4
# 4              0.953488                     3           Adelaide.1991.5
# 5              1.014644                     6           Adelaide.1991.6
# 6              0.868085                     9           Adelaide.1991.7
# 7              1.164962                     6           Adelaide.1991.9
# 8              1.244009                     2          Adelaide.1991.10
# 9              1.156687                     7          Adelaide.1991.11
# 10             0.780795                    13          Adelaide.1991.12
# 11             1.153420                     8          Adelaide.1991.13
# 12             0.868986                    14          Adelaide.1991.14
# 13             0.906189                     8          Adelaide.1991.15
# 14             1.240891                     4          Adelaide.1991.16
# 15             0.766219                    10          Adelaide.1991.17
# 16             1.166440                    12          Adelaide.1991.18
# 17             0.916251                     5          Adelaide.1991.19
# 18             1.044557                     1          Adelaide.1991.20
# 19             0.796037                    10          Adelaide.1991.21
# 20             1.036804                     6          Adelaide.1991.22
# 21             1.147743                     7          Adelaide.1991.24
# 17           1991-07-25
# 18           1991-08-02
# 19           1991-08-08
# 20           1991-08-15
# 21           1991-08-30
# 22           1992-03-20
# 23           1992-04-03
# 24           1992-04-09
# 25           1992-04-17
# 26           1992-04-23
# 27           1992-05-01
# 28           1992-05-06
# 29           1992-05-14
# ...                 ...
# 29920        2015-08-20
# 29921        2015-08-27
# 29922        2015-09-03
# 29923        2015-09-10
# 29924        2016-03-23
# 29925        2016-03-31
# 29926        2016-04-07
# 29927        2016-04-14
# 29928        2016-04-21
# 29929        2016-04-28
# 29930        2016-05-05
# 29931        2016-05-12
# 29932        2016-05-19
# 29933        2016-05-26
# 29934        2016-06-02
# 29935        2016-06-09
# 29936        2016-06-16
# 29937        2016-06-29
# 29938        2016-07-06
# 29939        2016-07-13
# 29940        2016-07-21
# 29941        2016-07-28
# 29942        2016-08-04
# 29943        2016-08-11
# 29944        2016-08-18
# 29945        2016-08-25
# 29946        2016-09-07
# 29947        2016-09-15
# 29948        2016-09-22
# 29949        2016-09-30
#
# [29950 rows x 87 columns]

# %%
ft_df.columns
# Out:
# Index(['team', 'oppo_team', 'round_type', 'venue', 'win_odds', 'line_odds',
#        'oppo_win_odds', 'oppo_line_odds', 'rolling_pred_win_rate',
#        'oppo_rolling_pred_win_rate', 'rolling_prev_match_kicks',
#        'rolling_prev_match_marks', 'rolling_prev_match_handballs',
#        'rolling_prev_match_goals', 'rolling_prev_match_behinds',
#        'rolling_prev_match_hit_outs', 'rolling_prev_match_tackles',
#        'rolling_prev_match_rebounds', 'rolling_prev_match_inside_50s',
#        'rolling_prev_match_clearances', 'rolling_prev_match_clangers',
#        'rolling_prev_match_frees_for', 'rolling_prev_match_frees_against',
#        'rolling_prev_match_contested_possessions',
#        'rolling_prev_match_uncontested_possessions',
#        'rolling_prev_match_contested_marks',
#        'rolling_prev_match_marks_inside_50',
#        'rolling_prev_match_one_percenters', 'rolling_prev_match_bounces',
#        'rolling_prev_match_goal_assists', 'rolling_prev_match_time_on_ground',
#        'last_year_brownlow_votes', 'oppo_rolling_prev_match_kicks',
#        'oppo_rolling_prev_match_marks', 'oppo_rolling_prev_match_handballs',
#        'oppo_rolling_prev_match_goals', 'oppo_rolling_prev_match_behinds',
#        'oppo_rolling_prev_match_hit_outs', 'oppo_rolling_prev_match_tackles',
#        'oppo_rolling_prev_match_rebounds',
#        'oppo_rolling_prev_match_inside_50s',
#        'oppo_rolling_prev_match_clearances',
#        'oppo_rolling_prev_match_clangers', 'oppo_rolling_prev_match_frees_for',
#        'oppo_rolling_prev_match_frees_against',
#        'oppo_rolling_prev_match_contested_possessions',
#        'oppo_rolling_prev_match_uncontested_possessions',
#        'oppo_rolling_prev_match_contested_marks',
#        'oppo_rolling_prev_match_marks_inside_50',
#        'oppo_rolling_prev_match_one_percenters',
#        'oppo_rolling_prev_match_bounces',
#        'oppo_rolling_prev_match_goal_assists',
#        'oppo_rolling_prev_match_time_on_ground',
#        'oppo_last_year_brownlow_votes', 'date', 'score', 'oppo_score', 'year',
#        'round_number', 'at_home', 'out_of_state', 'travel_distance',
#        'last_week_goals', 'last_week_behinds', 'last_week_result',
#        'last_week_score', 'cum_win_points', 'rolling_last_week_win_rate',
#        'win_streak', 'elo_rating', 'oppo_travel_distance',
#        'oppo_last_week_goals', 'oppo_last_week_behinds',
#        'oppo_last_week_result', 'oppo_last_week_score', 'oppo_cum_win_points',
#        'oppo_rolling_last_week_win_rate', 'oppo_win_streak', 'oppo_elo_rating',
#        'cum_percent', 'ladder_position', 'oppo_cum_percent',
#        'oppo_ladder_position', 'team_match_id', 'match_id', 'day_after_match',
#        'round_start_date'],
#       dtype='object')

# %%
# Make team-match entity as base

variable_types = {
    'team': vtypes.Categorical,
    'oppo_team': vtypes.Categorical,
    'round_type': vtypes.Categorical,
    'venue': vtypes.Categorical,
    'year': vtypes.Ordinal,
    'round_number': vtypes.Ordinal,
    'at_home': vtypes.Boolean,
    'out_of_state': vtypes.Boolean,
    # These really should be 'last_week_win', 'oppo_last_week_win'
    'last_week_result': vtypes.Boolean,
    'oppo_last_week_result': vtypes.Boolean,
    'ladder_position': vtypes.Ordinal,
    'oppo_ladder_position': vtypes.Ordinal,
}

es = ft.EntitySet('Team Matches')
es = es.entity_from_dataframe(
    entity_id='team_matches',
    dataframe=ft_df,
    index='team_match_id',
    time_index='date',
    secondary_time_index={'day_after_match': ['score', 'oppo_score']},
    variable_types=variable_types
)

# Add match entity
es.normalize_entity('team_matches', 'matches', 'match_id', additional_variables=['venue'])
# Add team entity
es.normalize_entity('team_matches', 'teams', 'team', make_time_index=False)
# Add venue entity
es.normalize_entity('matches', 'venues', 'venue', make_time_index=False)
# Add year entity
es.normalize_entity('team_matches', 'years', 'year', make_time_index=False)
# Add round_number entity
es.normalize_entity('team_matches', 'round_numbers', 'round_number',
                    additional_variables=['round_type'], make_time_index=False)

# Take the index and the day before the first match of the round to use as a cutoff time
cutoff_times = (es['team_matches']
                .df[['team_match_id', 'round_start_date', 'score', 'oppo_score']]
                .sort_values(by='round_start_date'))

es
# Out:
# Entityset: Team Matches
#   Entities:
#     team_matches [Rows: 29950, Columns: 85]
#     matches [Rows: 14981, Columns: 3]
#     teams [Rows: 20, Columns: 1]
#     venues [Rows: 44, Columns: 1]
#     years [Rows: 120, Columns: 1]
#     round_numbers [Rows: 28, Columns: 2]
#   Relationships:
#     team_matches.match_id -> matches.match_id
#     team_matches.team -> teams.team
#     matches.venue -> venues.venue
#     team_matches.year -> years.year
#     team_matches.round_number -> round_numbers.round_number

# %%
# Generate features using the constructed entityset
fm, features = ft.dfs(entityset=es,
                      target_entity='team_matches',
                      agg_primitives=["sum", "std", "max", "skew", "min", "mean", "count", "percent_true",
                                      "last", "trend", "time_since_last"],
                      trans_primitives=["day", "year", "month"]
                      ['weekend', 'weekday', 'day', 'month', 'year', 'time_since_previous'],
                      max_depth=2,
                      approximate='24h',
                      cutoff_time=cutoff_times,
                      verbose=True)
